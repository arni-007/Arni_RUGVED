# %%
#1.) Count the total number of matches conducted in 2008.

import pandas as pd

df= pd.read_csv(r'C:\Users\Arni\OneDrive\Desktop\RUGVED\task2\Matches.csv')

ndf=df[(df['season']==2008)]

count= ndf.shape[0]

print(f"The number of matches in 2008 were {count}")
# Out:
# The number of matches in 2008 were 58

# %%
#Find the cities where the maximum and minimum number of matches were conducted.

import pandas as pd

df= pd.read_csv(r'C:\Users\Arni\OneDrive\Desktop\RUGVED\task2\Matches.csv')

city_counts=df['city'].value_counts()

print(city_counts)

max_city= city_counts.idxmax()
max_count=city_counts.max()

min_city=city_counts.idxmin()
min_count=city_counts.min()

print(f"City with maximum matches: {max_city} - {max_count}")
print(f"City with maximum matches: {min_city} - {min_count}")
# Out:
# city
# Mumbai            101
# Kolkata            77
# Delhi              74
# Bangalore          66
# Hyderabad          64
# Chennai            57
# Jaipur             47
# Chandigarh         46
# Pune               38
# Durban             15
# Bengaluru          14
# Visakhapatnam      13
# Centurion          12
# Ahmedabad          12
# Mohali             10
# Rajkot             10
# Dharamsala          9
# Indore              9
# Johannesburg        8
# Port Elizabeth      7
# Abu Dhabi           7
# Cape Town           7
# Ranchi              7
# Cuttack             7
# Sharjah             6
# Raipur              6
# Kochi               5
# Kanpur              4
# Kimberley           3
# Nagpur              3
# East London         3
# Bloemfontein        2
# Name: count, dtype: int64
# City with maximum matches: Mumbai - 101
# City with maximum matches: Bloemfontein - 2

# %%
#3.) Find total count of matches city-wise. 

import pandas as pd

df=pd.read_csv(r"C:\Users\Arni\OneDrive\Desktop\RUGVED\task2\Matches.csv")

city_count=df['city'].value_counts()

city_count.head(5)
# Out:
# city
# Mumbai       101
# Kolkata       77
# Delhi         74
# Bangalore     66
# Hyderabad     64
# Name: count, dtype: int64

# %%
#4.) Tally the toss decisions each team has taken

import pandas as pd

df=pd.read_csv(r"C:\Users\Arni\OneDrive\Desktop\RUGVED\task2\Matches.csv")


toss_counts = df.groupby(['toss_winner', 'toss_decision']).size().reset_index(name='count')

toss_counts
# Out:
#                     toss_winner toss_decision  count
# 0           Chennai Super Kings           bat     48
# 1           Chennai Super Kings         field     41
# 2               Deccan Chargers           bat     24
# 3               Deccan Chargers         field     19
# 4                Delhi Capitals           bat      2
# 5                Delhi Capitals         field      8
# 6              Delhi Daredevils           bat     29
# 7              Delhi Daredevils         field     51
# 8                 Gujarat Lions           bat      1
# 9                 Gujarat Lions         field     14
# 10              Kings XI Punjab           bat     26
# 11              Kings XI Punjab         field     55
# 12         Kochi Tuskers Kerala           bat      3
# 13         Kochi Tuskers Kerala         field      5
# 14        Kolkata Knight Riders           bat     30
# 15        Kolkata Knight Riders         field     62
# 16               Mumbai Indians           bat     44
# 17               Mumbai Indians         field     54
# 18                Pune Warriors           bat     11
# 19                Pune Warriors         field      9
# 20             Rajasthan Royals           bat     32
# 21             Rajasthan Royals         field     48
# 22       Rising Pune Supergiant         field      6
# 23      Rising Pune Supergiants           bat      3
# 24      Rising Pune Supergiants         field      4
# 25  Royal Challengers Bangalore           bat     20
# 26  Royal Challengers Bangalore         field     61
# 27          Sunrisers Hyderabad           bat     20
# 28          Sunrisers Hyderabad         field     26

# %%
#5.) Count the total number of normal and tied matches. 

import pandas as pd

df=pd.read_csv(r'C:\Users\Arni\OneDrive\Desktop\RUGVED\task2\Matches.csv')

normal_count=(df[df['result']=='normal']['result'].count())
tie_count=(df[df['result']=='tie']['result'].count())

print(f"Normal Matches: {normal_count}\nTied Matched: {tie_count}")
# Out:
# Normal Matches: 743
# Tied Matched: 9

# %%
#6.) Find the teams where the result was a tie. 

import pandas as pd

df=pd.read_csv(r"C:\Users\Arni\OneDrive\Desktop\RUGVED\task2\Matches.csv")

tied=df[df['result']=='tie'][['id','season','date','team1','team2']]

print(f"The teams whose matches ended with tie are as follow:\n{tied}")
# Out:
# The teams whose matches ended with tie are as follow:
#         id  season        date                        team1  \
# 33      34    2017  2017-04-29                Gujarat Lions
# 125    126    2009  2009-04-23             Rajasthan Royals
# 189    190    2010  2010-03-21              Kings XI Punjab
# 387    388    2013  2013-04-07  Royal Challengers Bangalore
# 400    401    2013  2013-04-16             Delhi Daredevils
# 475    476    2014  2014-04-29             Rajasthan Royals
# 535    536    2015  2015-04-21             Rajasthan Royals
# 705  11146    2019    30/03/19        Kolkata Knight Riders
# 746  11342    2019    02/05/19               Mumbai Indians
#
#                            team2
# 33                Mumbai Indians
# 125        Kolkata Knight Riders
# 189          Chennai Super Kings
# 387          Sunrisers Hyderabad
# 400  Royal Challengers Bangalore
# 475        Kolkata Knight Riders
# 535              Kings XI Punjab
# 705               Delhi Capitals
# 746          Sunrisers Hyderabad

# %%
#7.) Find the team which won the match by the highest and lowest number of runs. 

import pandas as pd

df=pd.read_csv(r"C:\Users\Arni\OneDrive\Desktop\RUGVED\task2\Matches.csv")

highest_run=df['win_by_runs'].max()
lowest_run=df[df['win_by_runs']>0]['win_by_runs'].min()

high_team=df[df['win_by_runs']==highest_run]['winner'].unique()
lowest_team=df[df['win_by_runs']==lowest_run]['winner'].unique()

print(f"Highest:\n{','.join(high_team)}-{highest_run} runs\nLowest:\n{','.join(lowest_team)}-{lowest_run} runs")
# Out:
# Highest:
# Mumbai Indians-146 runs
# Lowest:
# Mumbai Indians,Kings XI Punjab,Delhi Daredevils,Chennai Super Kings,Gujarat Lions,Royal Challengers Bangalore-1 runs

# %%
#8.) Calculate mean, median and standard deviation of ‘win_by_runs’ 

import pandas as pd

df=pd.read_csv(r'C:\Users\Arni\OneDrive\Desktop\RUGVED\task2\Matches.csv')

mean=df['win_by_runs'].mean()
median=df['win_by_runs'].median()
standard_dev=df['win_by_runs'].std()

print(f"Mean: {mean}\nMedian: {median}\nStandard Deviation: {standard_dev}")
# Out:
# Mean: 13.283068783068783
# Median: 0.0
# Standard Deviation: 23.47114399366638

# %%
#9.) Find the venue where the team won by the highest and lowest number of runs

import pandas as pd

df=pd.read_csv(r"C:\Users\Arni\OneDrive\Desktop\RUGVED\task2\Matches.csv")

high_run=df[df['win_by_runs']>0]['win_by_runs'].max()
low_run=df[df['win_by_runs']>0]['win_by_runs'].min()

max_win= df[df['win_by_runs']==high_run]['venue'].unique()
min_win= df[df['win_by_runs']==low_run]['venue'].unique()

print(f"Highest: {', '.join(max_win)}- {high_run} runs\nLowest: {', '.join(min_win)}- {low_run} run/runs")
# Out:
# Highest: Feroz Shah Kotla- 146 runs
# Lowest: Rajiv Gandhi International Stadium, Uppal, Wankhede Stadium, New Wanderers Stadium, Feroz Shah Kotla, Subrata Roy Sahara Stadium, MA Chidambaram Stadium, Chepauk, Punjab Cricket Association IS Bindra Stadium, Mohali, M. Chinnaswamy Stadium, Rajiv Gandhi Intl. Cricket Stadium- 1 run/runs

# %%
#10.) Find the players who have won ‘Player of the Match’ more than 3 times. 

import pandas as pd

df= pd.read_csv(r'C:\Users\Arni\OneDrive\Desktop\RUGVED\task2\Matches.csv')

name=df['player_of_match'].value_counts()

print(name)

condition=name[name>3].index.tolist()

print(f"The players who have won 'Player of the Match' more than 3 times are") 
{', '.join(condition)}
# Out:
# player_of_match
# CH Gayle          21
# AB de Villiers    20
# MS Dhoni          17
# RG Sharma         17
# DA Warner         17
#                   ..
# Imran Tahir        1
# K Paul             1
# K Ahmed            1
# S Gill             1
# S Hetmyer          1
# Name: count, Length: 226, dtype: int64
# The players who have won 'Player of the Match' more than 3 times are
# {'CH Gayle, AB de Villiers, MS Dhoni, RG Sharma, DA Warner, YK Pathan, SR Watson, SK Raina, G Gambhir, MEK Hussey, V Kohli, AM Rahane, DR Smith, A Mishra, V Sehwag, AD Russell, JH Kallis, KA Pollard, SE Marsh, SP Narine, AT Rayudu, RA Jadeja, Harbhajan Singh, UT Yadav, SR Tendulkar, Rashid Khan, RV Uthappa, AC Gilchrist, M Vijay, RR Pant, S Dhawan, A Nehra, HH Pandya, BJ Hodge, SL Malinga, SC Ganguly, BB McCullum, AJ Finch, DW Steyn, DPMD Jayawardene, JD Unadkat, KC Sangakkara, Sandeep Sharma, Yuvraj Singh, SPD Smith, JC Buttler, B Kumar, GJ Maxwell, SV Samson, JJ Bumrah, PA Patel, JP Faulkner, SK Warne, JP Duminy, SS Iyer, ML Hayden, KH Pandya, KD Karthik, NM Coulter-Nile, N Rana, CA Lynn, AR Patel, KL Rahul, F du Plessis, MK Pandey'}

# %%
#11.) Find all deliveries where the batsman scored a six. 

import pandas as pd

df=pd.read_csv(r"C:\Users\Arni\OneDrive\Desktop\RUGVED\task2\deliveries.csv")

condition= df[df['batsman_runs']==6][['match_id','batsman']]

condition
# Out:
#         match_id       batsman
# 10             1     DA Warner
# 47             1  MC Henriques
# 75             1  Yuvraj Singh
# 89             1  Yuvraj Singh
# 91             1  MC Henriques
# ...          ...           ...
# 178987     11415     SR Watson
# 179048     11415      DJ Bravo
# 179061     11415     SR Watson
# 179062     11415     SR Watson
# 179063     11415     SR Watson
#
# [8170 rows x 2 columns]

# %%
#12.) Compute the average runs scored in matches in all the venues.

import pandas as pd

df=pd.read_csv(r"C:\Users\Arni\OneDrive\Desktop\RUGVED\task2\Matches.csv")
df2=pd.read_csv(r"C:\Users\Arni\OneDrive\Desktop\RUGVED\task2\deliveries.csv")

match_runs = df2.groupby('match_id')['total_runs'].sum().reset_index()
match_venue = df[['id', 'venue']].rename(columns={'id': 'match_id'})
match_runs_venue = pd.merge(match_runs, match_venue, on='match_id')

venue_avg = match_runs_venue.groupby('venue')['total_runs'].agg(['mean', 'count']).reset_index()
venue_avg = venue_avg.rename(columns={'mean': 'average_runs', 'count': 'matches_played'})

venue_avg
# Out:
#                                                 venue  average_runs  \
# 0                                    ACA-VDCA Stadium    329.000000
# 1                                    Barabati Stadium    325.428571
# 2                                   Brabourne Stadium    349.272727
# 3                                        Buffalo Park    266.333333
# 4                               De Beers Diamond Oval    299.000000
# 5                          Dr DY Patil Sports Academy    282.941176
# 6   Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...    283.727273
# 7                 Dubai International Cricket Stadium    294.857143
# 8                                        Eden Gardens    309.831169
# 9                                    Feroz Shah Kotla    311.880597
# 10                            Feroz Shah Kotla Ground    322.857143
# 11                                         Green Park    324.500000
# 12       Himachal Pradesh Cricket Association Stadium    321.888889
# 13                             Holkar Cricket Stadium    324.444444
# 14                                  IS Bindra Stadium    354.714286
# 15                 JSCA International Stadium Complex    293.714286
# 16                                          Kingsmead    290.200000
# 17                              M Chinnaswamy Stadium    318.726027
# 18                          M. A. Chidambaram Stadium    280.750000
# 19                             M. Chinnaswamy Stadium    334.714286
# 20                    MA Chidambaram Stadium, Chepauk    320.326531
# 21            Maharashtra Cricket Association Stadium    327.190476
# 22                                      Nehru Stadium    272.600000
# 23                              New Wanderers Stadium    286.500000
# 24                                           Newlands    256.714286
# 25                                    OUTsurance Oval    264.500000
# 26  Punjab Cricket Association IS Bindra Stadium, ...    334.357143
# 27         Punjab Cricket Association Stadium, Mohali    313.914286
# 28          Rajiv Gandhi International Stadium, Uppal    305.232143
# 29                 Rajiv Gandhi Intl. Cricket Stadium    327.625000
# 30                       Sardar Patel Stadium, Motera    313.916667
# 31             Saurashtra Cricket Association Stadium    333.300000
# 32                             Sawai Mansingh Stadium    307.234043
# 33   Shaheed Veer Narayan Singh International Stadium    290.166667
# 34                            Sharjah Cricket Stadium    304.833333
# 35                               Sheikh Zayed Stadium    276.142857
# 36                                   St George's Park    290.428571
# 37                         Subrata Roy Sahara Stadium    279.705882
# 38                                    SuperSport Park    304.416667
# 39       Vidarbha Cricket Association Stadium, Jamtha    294.000000
# 40                                   Wankhede Stadium    323.958904
#
#     matches_played
# 0                2
# 1                7
# 2               11
# 3                3
# 4                3
# 5               17
# 6               11
# 7                7
# 8               77
# 9               67
# 10               7
# 11               4
# 12               9
# 13               9
# 14               7
# 15               7
# 16              15
# 17              73
# 18               8
# 19               7
# 20              49
# 21              21
# 22               5
# 23               8
# 24               7
# 25               2
# 26              14
# 27              35
# 28              56
# 29               8
# 30              12
# 31              10
# 32              47
# 33               6
# 34               6
# 35               7
# 36               7
# 37              17
# 38              12
# 39               3
# 40              73

# %%
#13.) Find the umpires who umpired the maximum number of times

import pandas as pd 

df=pd.read_csv(r"C:\Users\Arni\OneDrive\Desktop\RUGVED\task2\Matches.csv")

umpires = pd.concat([df['umpire1'], df['umpire2'], df['umpire3']]).dropna()

umpire_counts = umpires.value_counts()

#max_count = umpire_counts.max()
#ax_umpires = umpire_counts[umpire_counts == max_count]


print("Umpires who umpired the maximum number of times:")

umpire_counts.head(5)
# Out:
# Umpires who umpired the maximum number of times:
# S Ravi             114
# HDPK Dharmasena     87
# C Shamshuddin       83
# AK Chaudhary        58
# SJA Taufel          55
# Name: count, dtype: int64

# %%
#14.) Find the total number of matches played in each season. 

import pandas as pd

df=pd.read_csv(r"C:\Users\Arni\OneDrive\Desktop\RUGVED\task2\Matches.csv")

season=df.groupby('season')['season'].value_counts()

season
# Out:
# season
# 2008    58
# 2009    57
# 2010    60
# 2011    73
# 2012    74
# 2013    76
# 2014    60
# 2015    59
# 2016    60
# 2017    59
# 2018    60
# 2019    60
# Name: count, dtype: int64

# %%
#15.) Find total runs scored in each season. 

import pandas as pd

df=pd.read_csv(r"C:\Users\Arni\OneDrive\Desktop\RUGVED\task2\Matches.csv")
df2=pd.read_csv(r"C:\Users\Arni\OneDrive\Desktop\RUGVED\task2\deliveries.csv")

merged = pd.merge(df2[['match_id','total_runs']], df[['id', 'season']], left_on='match_id', right_on='id')

total_run= merged.groupby('season')[['season']].sum()

total_run
# Out:
#           season
# season
# 2008    27085912
# 2009    27334454
# 2010    29140980
# 2011    34213143
# 2012    35747204
# 2013    36590301
# 2014    28800200
# 2015    27508780
# 2016    28417536
# 2017    27959654
# 2018    28837220
# 2019    28928232

# %%
#16.) Calculate total number of runs scored by each batsman and display top 10.

import pandas as pd

df2=pd.read_csv(r"C:\Users\Arni\OneDrive\Desktop\RUGVED\task2\deliveries.csv")

runs= df2.groupby('batsman')['batsman_runs'].sum().sort_values(ascending=False)

runs.head(10)
# Out:
# batsman
# V Kohli           5434
# SK Raina          5415
# RG Sharma         4914
# DA Warner         4741
# S Dhawan          4632
# CH Gayle          4560
# MS Dhoni          4477
# RV Uthappa        4446
# AB de Villiers    4428
# G Gambhir         4223
# Name: batsman_runs, dtype: int64

# %%
#17.) Compute the total number of wickets taken by each bowler. 

import pandas as pd

df2=pd.read_csv(r"C:\Users\Arni\OneDrive\Desktop\RUGVED\task2\deliveries.csv")

wicket = df2[df2['player_dismissed'].notnull()].groupby('bowler')['player_dismissed'].count().sort_values(ascending=False)

wicket
# Out:
# bowler
# SL Malinga         188
# DJ Bravo           168
# A Mishra           165
# Harbhajan Singh    161
# PP Chawla          156
#                   ...
# AA Noffke            1
# AA Jhunjhunwala      1
# AJ Finch             1
# TP Sudhindra         1
# V Chakravarthy       1
# Name: player_dismissed, Length: 352, dtype: int64

# %%
#18.) Compute batting averages and display top 10.

import pandas as pd

df=pd.read_csv(r"C:\Users\Arni\OneDrive\Desktop\RUGVED\task2\Matches.csv")
df2=pd.read_csv(r"C:\Users\Arni\OneDrive\Desktop\RUGVED\task2\deliveries.csv")

total_runs = df2.groupby('batsman')['batsman_runs'].sum()

dismissals = df2[df2['player_dismissed'].notnull()].groupby('player_dismissed')['player_dismissed'].count()

batting_avg = (total_runs / dismissals).dropna().sort_values(ascending=False)

print(batting_avg.head(10))
# Out:
# J Bairstow        58.500000
# MN van Wyk        55.666667
# AC Voges          45.250000
# HM Amla           44.384615
# Iqbal Abdulla     44.000000
# DA Warner         43.100000
# KL Rahul          42.829787
# MS Dhoni          42.638095
# CH Gayle          41.834862
# PD Collingwood    40.600000
# dtype: float64

# %%
#19.) Visualize toss decisions across all seasons

import pandas as pd
import matplotlib.pyplot as mypy

df=pd.read_csv(r"C:\Users\Arni\OneDrive\Desktop\RUGVED\task2\Matches.csv")

#field_dec= df.groupby('season')[df['toss_decision'=='field']]['toss_decision'].value_counts()
#bat_dec=df.groupby('season')[df['toss_decision'=='bat']]['toss_decision'].value_counts()

#field_dec.plot(kind='line',color='magenta',marker='^')

# bat_dec.plot(kind='line',color='orange',marker='^')

toss_counts = df.groupby(['season', 'toss_decision']).size().unstack(fill_value=0)

toss_counts.plot(kind='bar', color=['green', 'cyan'])

mypy.xlabel('Toss Decision')
mypy.ylabel('Number of Matches')
mypy.xticks(rotation=45)
mypy.title('Toss Decision')
mypy.show()

# %%
#Practice

import numpy as np

l=[1,2,3,4]

arr=np.array(l)

mean1=arr.mean()
std1=arr.std()


print(f"mean: {mean1}, std: {std1}")
